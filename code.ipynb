# %% [markdown]
# # Trabalho 2 API Rest
# ## Authors: Gabriela Dellamora Paim, João Enrique Rego Cairuga, Luize Silveira Iensse, Matheus Maia da Silva
# ## Version: 2023.04.12
#
# Python Version: 3.9.12

# %% [markdown]
# # Imports

# %%
import requests
import flask

# %% [markdown]
# # 1. Escolher um conjunto de dados público para realização da tarefa.

# %%
dataset_url= r"https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/censo-da-educacao-superior"

# %% [markdown]
# # 2. Criar uma API Rest que permita:

# %% [markdown]
# a) Consulta - Método HTTP GET;

# %% [markdown]
# b) Atualização - Método HTTP PUT;

# %% [markdown]
# c) Inserção - Método HTTP POST;

# %% [markdown]
# d) Deleção - Método HTTP DELETE.

# %% [markdown]
# # 3. Consumir a API criada usando a lib requests. Explorar todas as operações da API.
